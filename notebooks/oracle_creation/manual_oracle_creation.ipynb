# %% [markdown]
# # Manually creating oracle to see if they are sufficient for the benchmark

# %%
from datasets import load_dataset


ds = load_dataset("CharlyR/vtikz", "tikz", split="benchmark")
ds = ds.select_columns(["id","type","instruction","code","image_solution","image_input","code_solution"])
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[2], line 4
#       1 from datasets import load_dataset
# ----> 4 ds = load_dataset("CharlyR/vtikz", "tikz", split="benchmark")
#       5 ds = ds.select_columns(["id","type","instruction","code","image_solution","image_input","code_solution"])
#
# File ~/Documents/AI/VIFagent/.venv/lib/python3.12/site-packages/datasets/load.py:2062, in load_dataset(path, name, data_dir, data_files, split, cache_dir, features, download_config, download_mode, verification_mode, keep_in_memory, save_infos, revision, token, streaming, num_proc, storage_options, trust_remote_code, **config_kwargs)
#    2057 verification_mode = VerificationMode(
#    2058     (verification_mode or VerificationMode.BASIC_CHECKS) if not save_infos else VerificationMode.ALL_CHECKS
#    2059 )
#    2061 # Create a dataset builder
# ...

# %%
from IPython.display import clear_output,display,HTML
import os

for row in ds.iter(1):
    if os.path.exists(
        f"notebooks/oracle_creation/manual_oracle_functions/{row["id"][0]}.py"
    ):
        continue
    with open(
        f"notebooks/oracle_creation/manual_oracle_functions/{row["id"][0]}.py", "w"
    ) as oracle_file:
        oracle_file.write("from vif.falcon.oracle.guided_oracle.expressions import (added,removed,angle,color,placement,position,size,shape,within)\ndef test_valid_customization() -> bool:\n  ")
    print(f"{row["id"][0]} : {row["instruction"][0]}")
    display(row["image_input"][0],row["image_solution"][0][0])
    break
# Out:
# zoomedtriangle_centered : Center the zoom at the green intersection point.
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=300x300>
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=300x300>
